# %%
import mlflow
import sklearn
from sklearn.datasets import load_iris
import pandas as pd

# %%
# mlflow.set_tracking_uri("http://localhost:5000")

# %%
run_id = "ae233d51f06e41a69a74cfa145596550"
model_uri = f"runs:/{run_id}/iris_model"

model_uri
# Out:
# 'runs:/ae233d51f06e41a69a74cfa145596550/iris_model'

# %%
model = mlflow.pyfunc.load_model(model_uri)

# %%
X,y = load_iris(return_X_y=True)

# %%
predictions = model.predict(X)

# %%
iris_features_names = load_iris().feature_names

# %%
results = pd.DataFrame(
    X,
    columns=iris_features_names
)

results["predicted_label"] = predictions
results["actual_label"] = y

# %%
results[50:80]
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
# 55                5.7               2.8                4.5               1.3
# 56                6.3               3.3                4.7               1.6
# 57                4.9               2.4                3.3               1.0
# 58                6.6               2.9                4.6               1.3
# 59                5.2               2.7                3.9               1.4
# 60                5.0               2.0                3.5               1.0
# ...
